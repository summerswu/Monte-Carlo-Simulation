# %%
from numpy import sqrt,linspace
from numpy.random import uniform

from bokeh.plotting import figure 
from bokeh.io import show, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="febefdcf-a2cc-444a-ae79-5a2c62c5b386">Loading BokehJS ...</span>
#     </div>

# %%
xs = linspace(0,1,1000)
ys = sqrt(1 - xs **2)

SIZE = 100000

pts = uniform(0, 1, size=(SIZE, 2))
inside = pts[:,0]**2 + pts[:,1] ** 2 <1


fig = figure()
fig.line(xs, ys, color = 'blue')

fig.scatter(pts[inside][:,0], pts[inside][:,1])
fig.scatter(pts[~inside][:,0], pts[~inside][:,1],color='red')

show(fig)
# Out:
#   <div class="bk-root" id="25a8f4f8-1421-49f0-b13b-fa987adf8826"></div>

# %%
print(sum(inside)/SIZE*4)
# Out:
# 3.1492
