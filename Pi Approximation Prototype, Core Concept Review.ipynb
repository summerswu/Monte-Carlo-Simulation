# %%
from numpy import sqrt,linspace
from numpy.random import uniform

from bokeh.plotting import figure 
from bokeh.io import show, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cbafdad2-a4dd-4d4f-a207-107d1a0f7cac">Loading BokehJS ...</span>
#     </div>

# %%
xs = linspace(0,1,1000)
ys = sqrt(1 - xs **2)

SIZE = 1000

pts = uniform(0, 1, size=(SIZE, 2))
inside = pts[:,0]**2 + pts[:,1] ** 2 <1


fig = figure()
fig.line(xs, ys, color = 'blue')

fig.scatter(pts[inside][:,0], pts[inside][:,1])
fig.scatter(pts[~inside][:,0], pts[~inside][:,1],color='red')

show(fig)
# Out:
#   <div class="bk-root" id="a41821d0-c3c4-4684-9dff-4f9aa2cc7497"></div>

# %%
print(sum(inside)/SIZE*4)
# Out:
# 3.152
